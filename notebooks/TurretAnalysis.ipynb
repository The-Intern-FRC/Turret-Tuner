# %% [markdown]
# # 🎯 Turret Log Analysis Notebook
# Load logs, visualize shot distributions, hit rates, and suggested tuning margins.

# %%
import pandas as pd
from analysis import analyzer
logs = analyzer.read_logs('data/raw')
print(logs.head())
